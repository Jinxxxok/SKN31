# %% [markdown]
# # 프롬프트 엔지니어링(Prompt Engineering)
#
# ## 프롬프트(Prompt)
#
# - 프롬프트(Prompt)는 생성형 인공지능 모델에게 작업을 요청하거나 지시하기 위해 입력하는 정보이다.
# - 일반적으로 자연어로 작성되지만, 이미지, 음성, 동영상 등의 다양한 형태로 입력될 수도 있다.
# - 생성형 인공지능 모델은 프롬프트를 바탕으로 텍스트, 이미지, 코드 등 다양한 결과를 생성한다.
#
# ## 프롬프트 엔지니어링이란
#
# - **프롬프트 엔지니어링**은 LLM이 원하는 결과를 안정적으로 생성하도록 **지시문, 입력 정보, 출력 형식, 예시, 제약 조건을 설계하는 작업**이다.
#     - OpenAI는 프롬프트 엔지니어링 정의:  "모델이 요구사항을 만족하는 콘텐츠를 **일관되게 생성하도록 효과적인 지시를 작성**하는 과정"
#     - LLM 출력은 비결정적이지만, 프롬프트에 역할, 예시, 평가 등을 사용하여 구체화 하면 더 일관된 결과를 얻을 수 있다.
#     - 예를 들어 단순히 다음처럼 요청하면 결과가 들쭉날쭉하고 장황해 질 수 있다.
#
#         ```text
#         프롬프트 엔지니어링 설명해줘.
#         ```
#
#         반면 다음처럼 요청하면 더 안정적인 결과를 얻을 수 있다.
#
#         ```text
#         너는 AI를 초보자에게 가르치는 강사이다.
#         프롬프트 엔지니어링을 초보자에게 설명하라.
#
#         조건:
#         - 먼저 한 문장으로 정의한다.
#         - 그다음 원칙 5개를 표로 정리한다.
#         - 마지막에 좋은 프롬프트와 나쁜 프롬프트 예시를 비교한다.
#         - 한국어로 작성한다.
#         ```
#
#     -  프롬프트 엔지니어링은 **AI에게 막연히 질문하는 기술이 아니라, 원하는 작업을 수행하도록 명세서를 작성하는 기술** 이다.
#
#
# ## 프롬프트 엔지니어링의 발전
#   - 프롬프트 엔지니어링 -> 컨텍스트 엔지니어링 -> 하네스 엔지니어링
#   - **프롬프트 엔지니어링은 모델에게 '무엇을 하라고 지시할 것인가'**, **컨텍스트 엔지니어링은 '모델에게 어떤 정보를 제공할 것인가'**, **하네스 엔지니어링은 '모델이 실제로 일하게 만드는 실행 환경을 어떻게 설계할 것인가'** 를 말한다.
#
#
# | 구분         | 핵심 질문                         | 주요 대상                        |
# | ---------- | ----------------------------- | ---------------------------- |
# | 프롬프트 엔지니어링 | 모델에게 어떻게 지시할 것인가?             | 지시문, 역할, 형식, 예시              |
# | 컨텍스트 엔지니어링 | 모델에게 어떤 정보를 제공할 것인가?        | RAG, 검색결과, 도구 결과, 메모리, 대화 이력       |
# | 하네스 엔지니어링  | 모델을 어떤 시스템 안에서 어떻게 실행·검증·통제할 것인가? | 가드레일(Guardrails), 에이전트 피드백 루프, 코딩표준, 아키텍처 규칙, 도구, 권한, 테스트, 로깅, 검증 |

# %% [markdown]
# ## 프롬프트 엔지니어링의 원칙
#
# ### 1. 목표를 명확히 하고 내용을 구체적으로 작성한다. (명확성, 구체성)
#
# 좋은 프롬프트는 "무엇을 해줘"가 아니라 **무엇을, 누구를 위해, 어떤 수준으로, 어떤 형식으로** 해달라는 요청을 포함한다.
# - 프롬프트는 생성형 인공지능 모델이 수행해야 할 작업을 명확하고 구체적으로 설명해야 한다.
# - 모호하거나 불완전한 지시를 제공하면 모델은 사용자의 의도를 정확하게 파악하기 어렵고, 기대와 다른 결과를 생성할 수 있다.
# - 따라서 수행할 작업, 원하는 결과의 형식, 대상 독자, 분량, 제약 조건 등을 가능한 한 구체적으로 제시하는 것이 좋다.
#
# 나쁜 예:
#
# ```text
# 머신러닝 설명해줘.
# ```
#
# 좋은 예:
#
# ```text
# 머신러닝을 처음 배우는 비전공자를 대상으로 설명해줘.
# 머신러닝의 정의, 지도학습/비지도학습 차이, 실제 활용 예시를 포함하고, 마지막에 5문장으로 요약해줘.
# ```
#
# Anthropic도 프롬프트를 개선하기 전에 먼저 **성공 기준을 명확히 정의하고, 그 기준을 경험적으로 테스트할 방법을 갖추는 것**을 권장한다.
#
#
# ### 2. 역할(Persona)을 지정한다
#
# 모델에게 역할(Persona)을 주면 답변의 관점과 깊이가 달라진다.
# 역할 지정은 단순한 "연기"가 아니라, **답변 기준, 용어 선택, 예시의 수준, 판단 기준을 좁히는 장치** 이다.
#
# 예1:
#
# ```text
# 당신은 10년 차 경력의 숙련된 UX 디자이너입니다.
# 사용자 중심 디자인과 데이터 기반 의사결정에 강점이 있습니다.
# 신규 모바일 쇼핑 앱의 첫 화면 구성안을 제안해야 합니다.
#
# ...
#
# 위 역할을 바탕으로 화면 구성을 제안해주세요.
# ```
#
# 예2:
# ```text
# 당신은 10년 차 전문 헬스 트레이너이다.
# 체지방을 줄이고 근육량을 늘리고 싶은 30대 직장인 남성을 위한 1주일 운동 스케쥴을 작성해줘.
# ...
# ```
#
# ### 3. 출력 형식을 명확히 지정한다
#
# LLM은 기본적으로 자유형 텍스트를 생성하므로, 원하는 결과 형식이 있으면 명시해야 한다. API나 자동화 시스템에서는 특히 중요하다.
#
# 예:
#
# ```text
# ...
#
# 결과를 JSON  형식으로 작성해줘.
#
# {
#   "person": "김철수",
#   "task": "보고서 제출",
#   "due_date": "2025-12-31"
# }
#
# ```
#
#
# ### 4. 필요한 배경 정보(Context-맥락 정보)를 제공한다
#
# - 모델은 사용자의 상황을 자동으로 알지 못한다. 따라서 답변에 필요한 배경 정보가 있다면 넣어야 한다.
# - 모델 답변의 할루시네이션을 방지하기 위해 다양한 형태의 정보를 Context에 포함하여 제공할 수 있다. 이런 정보에는 사내 업무 문서, 웹 검색정보, 데이터베이스 등에서 조회한 관련 정보들이 있을 수 있다.
#
#
# ```text
# 우리는 월 20%의 고객 이탈률을 겪고 있는 구독 기반 온라인 교육 서비스이다.
# 주요 고객층은 30대 직장인이고, 이탈 주요 원인은 콘텐츠 부족과 동기 저하이다.
# 이탈률을 줄이기 위한 실질적인 전략을 제안해줘.
# ```
#
# ### 5. 예시를 제공한다
#
# 모델에게 원하는 입출력 예시를 주면 결과가 안정된다.
# 예시의 개수에 따라 **Zero shot Learning**, **One shot Learning**, **Few shot Learning** 이 있다.
#
# ```text
#
# 예시:
# 질문: "과적합이란 무엇인가요?"
# 답변:
#     - 정의: 학습 데이터에는 잘 맞지만 새로운 데이터에는 성능이 낮아지는 현상
#     - 비유: 문제집 답을 외웠지만 새로운 문제를 못 푸는 상황
#     - 예시: 훈련 정확도 99%, 테스트 정확도 70%
# ```
#
# ### 6. 프롬프트 구성을 구조화한다.
# 긴 프롬프트는 역할(Role), 지시(Instruction), 맥락(Context), 출력 형식(Output Format) 등을 구획으로 나눈다. 나눌 때는 **태그**(예: `<context>, <instructions>`)나 **Markdown**(`#`, `##`)를 이용한다.
#
# ```xml
# <instructions>
# 다음 뉴스 기사를 읽고 핵심 내용을 요약하라.
# </instructions>
#
# <context>
# 사용자는 바쁜 직장인으로, 전체 기사를 읽을 시간이 없다. 핵심 정보만 빠르게 파악하고 싶어한다.
# </context>
#
# <input_data>
# [기사 원문]
# 오늘 오전, 서울 강남구 일대에 시간당 80mm가 넘는 집중호우가 내려 도로 일부가 침수되고, 차량 통제가 이루어졌다. 기상청은 이 같은 집중호우가 오후까지 계속될 것으로 전망하면서 시민들의 외출 자제를 당부했다. 서울시 역시 재난 문자를 통해 대중교통 이용을 권고하고 있다. ...
# </input_data>
#
# <output_format>
# 한 문단(3줄 이내)으로 요약하라. 일반인이 쉽게 이해할 수 있는 문장을 사용하라.
# </output_format>
#
# <constraints>
# - 전문 용어에는 반드시 쉬운 설명을 덧붙일 것
# - 분량은 500자 이내 한다.
# - 한국어로 작성한다.
# </constraints>
# ```
#
#
# ### 7. 제약 조건을 명시한다
#
# - 모델이 하지 말아야 할 것도 명확히 써야 한다.
# - 특히 교육, 법률, 의료, 투자, 기업 보고서처럼 정확성이 중요한 영역에서는 **출처, 기준 시점, 불확실성, 검증 절차**를 프롬프트에 포함하는 것이 좋다.
#
# 예:
#
# ```text
# 주의:
# - 모르는 내용은 추측하지 말고 모른다고 말한다.
# - 현재 날짜 2XXX 년 10월 20일을 기준으로 최신정보를 제공한다.
# - 코드는 Python 3.12 기준으로 작성한다.
# ```
#
# ### 8. 프롬프트를 점진적으로 개선한다.
#
# 실무에서는 프롬프트를 한 번 작성하고 끝내지 않는다. 원하는 결과가 안정적으로 나오는지 반복적으로 평가하고 튜닝해야 한다.
# 프롬프트를 평가할 때는 평가에 사용할 LLM 모델의 버전 고정하여 프롬프트 수정 후 결과가 달라졌을 때, 그 변화가 모델 변경 때문인지 프롬프트 변경 때문인지 구분할 수 있도록 한다.
# 테스트 질문, 기대 답변, 평가 기준을 미리 정해두고 프롬프트 성능을 측정하는 평가 방식을 구축한다. 이를 통해 프롬프트를 수정할 때마다 정확도, 형식 준수 여부, 누락 여부, 환각 여부 등의 변화를 모니터링할 수 있다.

# %% [markdown]
# # 프롬프트 템플릿 (Prompt Template)
#
# 프롬프트 템플릿은 언어 모델(Large Language Model, LLM)에 입력할 **프롬프트를 생성하는 재사용 가능한 템플릿**이다. 프롬프트 작성 시 변수를 포함하여 템플릿화함으로써, 다양한 입력값에 유연하게 대응할 수 있으며, 일관성 있는 결과를 얻는 데 유리하다.
# 프롬프트는 문자열(string)로 작성되므로 Python의 f-string을 사용해 동적으로 생성할 수 있다. 또한 LangChain은 다양한 PromptTemplate 클래스를 제공하여 변수 치환, 프롬프트 재사용, 체계적인 프롬프트 관리를 지원한다.
#
# ## 프롬프트 템플릿의 목적
#
# * 재사용성: 입력값이 달라져도 동일한 프롬프트 구조를 재사용할 수 있다.
# * 유지보수성 향상: 프롬프트 구조와 변수 값을 분리하여 관리할 수 있으므로 수정과 관리가 용이하다.
# * 자동화 지원: 사용자 입력, 데이터베이스 조회 결과, 웹 검색 결과 등 다양한 데이터를 템플릿에 주입하여 프롬프트를 자동으로 생성할 수 있다.
# * 일관성 확보: 동일한 형식의 프롬프트를 지속적으로 생성하여 모델의 응답 품질을 보다 안정적으로 유지할 수 있다.
#
# ## Langchain의 주요 Prompt Template
#
# 1. **PromptTemplate**
#
# * **단일 텍스트(string) 형태의 프롬프트를 생성**하기 위한 가장 기본적인 템플릿 클래스이다.
# * 특징
#     * 문자열 기반 프롬프트 생성에 사용된다.
#     * 변수(Placeholder)는 중괄호 {}로 표시한다.
#       * `{}`는 변수를 표시하는 구분자로 사용된다. 그래서 프롬프트에 중괄호 자체를 문자열로 포함하려면 `{{`와 `}}`를 사용하여 이스케이프(escape)해야 한다.
#     * 변수(placeholder)에 전달되는 입력값에 따라 프롬프트를 동적으로 생성할 수 있다.
#     * 주로 텍스트 완성(Text Completion) 방식이나 단순 지시형 프롬프트 작성에 적합하다.
#
# 2. **ChatPromptTemplate**
#
# * 대화형(Chat) 언어 모델을 위한 프롬프트 템플릿 클래스이다.
# * 시스템(System), 사용자(Human), AI(AI) 등의 역할(Role)을 가진 메시지들을 조합하여 프롬프트를 구성할 수 있다.
# * 특징
#     * 역할(Role) 기반 메시지를 정의할 수 있다.
#     * 시스템 메시지(SystemMessage), 사용자 메시지(HumanMessage), AI 메시지(AIMessage) 등을 하나의 프롬프트로 구성할 수 있다.
#     * 대화 이력이나 컨텍스트를 구조적으로 관리하기 쉽다.
#     * GPT 계열과 같은 채팅 모델에서 가장 많이 사용되는 프롬프트 템플릿이다.
#
# - 최근의 GPT, Claude, Gemini, Qwen과 같은 대부분의 LLM은 채팅(Chat) 인터페이스를 기반으로 동작하므로, PromptTemplate보다 ChatPromptTemplate이 더 널리 사용된다.

# %% [markdown]
# ## 프롬프트 템플릿 사용법
#
# - 전체 템플릿은 문자열(string)로 정의하며, 변수(placeholder)는 `{변수명}` 형식으로 지정한다. 템플릿이 실행될 때 변수는 전달된 실제 값으로 대체된다.
#   - 예시: `"{country}의 수도는 어디인가요?"`
# - 프롬프트에 중괄호(`{, }`) 자체를 포함하려면 `{{` 와 `}}`를 사용하여 이스케이프(escape)해야 한다.
#   - 예시: `{{"이름": "{name}"}}`
# - 생성한 문자열 템플릿을 이용하여 Prompt Template 객체를 생성한다.
#
# ### 공통 메소드
#
# 프롬프트 템플릿 클래스에서 공통적으로 사용하는 주요 메소드는 다음과 같다.
#
# #### 템플릿 생성 메소드
#
# - **from_template()**
#   - 문자열 기반 템플릿을 생성한다.
#   - `PromptTemplate`과 `ChatPromptTemplate` 모두에서 사용할 수 있다.
#
# - **from_messages()**
#   - 메시지 객체를 이용하여 대화형 템플릿을 생성한다.
#   - `ChatPromptTemplate`에서 사용한다.
#
# #### 프롬프트 생성 메소드
#
# - **format(변수=값, ...)**
#   - 변수에 값을 대입하여 최종 프롬프트 문자열을 생성한다.
#
# - **format_messages(변수=값, ...)**
#   - 메시지 리스트 형식의 프롬프트를 생성한다.
#   - `ChatPromptTemplate`에서 사용한다.
#
# - **invoke(dict)**
#   - 변수와 값을 딕셔너리 형태로 전달하여 프롬프트를 생성한다. 생성된 프롬프트는 `PromptValue` 객체로 반환된다.
#   - 생성된 결과는 Runnable 체인의 다음 단계 입력으로 사용할 수 있다.
#
# > ##### `invoke()` 메소드
# >
# > - invoke()는 LangChain의 핵심 인터페이스인 Runnable에서 제공하는 공통 실행 메소드이다.
# > - Runnable은 LangChain의 실행 가능한 객체들이 따르는 공통 인터페이스이다.
# > - PromptTemplate, ChatModel, OutputParser, Chain 등은 모두 Runnable 인터페이스를 구현한다.
# > - invoke()는 입력을 받아 처리한 뒤 결과를 반환한다.
# > - 여러 Runnable 객체를 연결하여 체인(Chain)을 구성할 수 있으며, 각 단계의 출력은 다음 단계의 입력으로 전달된다.

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
# input_variable ({변수명}-{country}) => 나중에 채울값.

template = "{country}의 수도는 어디인가요?"
prompt = PromptTemplate.from_template(
    template= template
)
prompt
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}의 수도는 어디인가요?')

# %%
print(prompt.template)
print(prompt.input_variables)
# Out:
# {country}의 수도는 어디인가요?
# ['country']

# %%
# prompt 생성 -> input_variables에 값을 할당.
p_str= prompt.format(country= "한국")
print(p_str)
p_str2 = prompt.format(country= "미국")
print(p_str2)
# Out:
# 한국의 수도는 어디인가요?
# 미국의 수도는 어디인가요?

# %%
p_str3 = prompt.invoke({"country":"독일"})
p_str3
# Out:
# StringPromptValue(text='독일의 수도는 어디인가요?')

# %%
# Prompt -> Model
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

# 프롬프트 템플릿 생성
prompt = PromptTemplate.from_template(template= "{country}의 수도를 알려주세요.")
# 모델 생성
model = ChatOpenAI(model= "gpt-5.4-nano")
# 프롬프트 템플릿의 input_variables에 값을 넣어서 프롬프트 생성
query = prompt.invoke({"country":"한국"}) # prompt.format(country="한국")
# 모델에 프롬프트를 입력해서 질의 요청
response = model.invoke(query)

# %%
print(response) # 응답: AIMessage 타입
print(response.content) # 응답: text만 조회
# Out:
# content='한국의 수도는 **서울(Seoul)** 입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 13, 'total_tokens': 28, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DtNzVm5PwcxUlvjHQrOogDftoR2f0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019eecff-a3bd-7e62-ac0d-5f786e085bc8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 15, 'total_tokens': 28, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 한국의 수도는 **서울(Seoul)** 입니다.

# %%
query2 = prompt.invoke({"country":"영국"})
response2 = model.invoke(query2)

# %%
response2.content
# Out:
# '영국의 수도는 **런던(London)** 입니다.'

# %%
while True:
    country = input("수도를 알고 싶은 나라이름을 입력하세요:")
    if country == '!q':
        break
    else:
        query = prompt.invoke({"country":country})
        response = model.invoke(query)
        print(f"질문: {query}")
        print(f"답변: {response.content}")
# Out:
# 질문: text='한국의 수도를 알려주세요.'
# 답변: 한국의 수도는 **서울특별시**입니다.

# %%
# prompt template --[query]--> model
chain = prompt | model
res = chain.invoke({"country":"나이지리아"}) # prompt에 전달할 값을 입력.

# %%
res.content
# Out:
# '나이지리아의 수도는 **아부자(Abuja)** 입니다.'

# %%
# input variable이 여러개인 프롬프트 템플릿
prompt2 = PromptTemplate.from_template(
    template="{place1}, {place2}간의 거리는 얼마나 되는지 KM로 알려주세요."
)
print(prompt2.input_variables)

print(prompt2.format(place1="서울", place2="런던"))
print(prompt2.invoke({"place1":"부산", "place2":"서울"}))
# Out:
# ['place1', 'place2']
# 서울, 런던간의 거리는 얼마나 되는지 KM로 알려주세요.
# text='부산, 서울간의 거리는 얼마나 되는지 KM로 알려주세요.'

# %%
query = prompt2.invoke({"place1":"부산", "place2":"서울"})
res = model.invoke(query)

# %%
print(res.content)
# Out:
# 부산–서울 사이는 **약 325~400 km** 정도입니다.
#
# - **직선거리(항공 기준)**: 약 **325 km**
# - **도로 주행거리**(고속도로 기준, 경로에 따라 다름): 대략 **400 km 전후**
#
# 원하시면 **출발/도착 지점(예: 부산역–서울역)**을 지정해 주시면 그 경로 기준으로 더 정확히 계산해 드릴게요.

# %%
########################################
# ChatPromptTemplate
#
# Chatting 형식의 Message를 지원.
#   - chatting형식: Role- Content(메세지)로 구성
#   - Langchain 방식
[
    ("role","content"), ("role",'content'), ...
]
# - OpenAI 방식 구성
[
    {"role":"작성자Role", "content":"작성메세지"}, ...
]
# - Langchain에서는 위 두가지 방식 다 지원.
# Role
## user/human   : 사용자 메세지
## ai/assistant : LLM 메세지
## system       : 전체 대화에 공통적으로 적용될 규칙이나 지침을 지정하는 메세지.


## tool(ToolMessage) : Tool calling에서 Tool의 처리결과를 담은 메세지.
# Out:
# [{'role': '작성자Role', 'content': '작성메세지'}, Ellipsis]

# %%
from langchain_core.prompts import ChatPromptTemplate


message=[
    ("system", "당신은 {domain} 전문 Assistant입니다. 모든 답변은 {word_length}개 단어 이하로 답해주세요."),
    ("user","{query}")
]

prompt = ChatPromptTemplate.from_messages(
    messages= message
)
print(prompt.input_variables)
# Out:
# ['domain', 'query', 'word_length']

# %%
query1 = prompt.format_messages(domain="AI", word_length=30, query="Agent란 무엇인가요?")
query1
# role:system => SystemMessage객체
# role: user/human = > HumanMessage 객체
# role: ai./assistant => AIMessage 객체
# Out:
# [SystemMessage(content='당신은 AI 전문 Assistant입니다. 모든 답변은 30개 단어 이하로 답해주세요.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Agent란 무엇인가요?', additional_kwargs={}, response_metadata={})]

# %%
res = model.invoke(query1)

# %%
print(res.content)
# Out:
# Agent는 특정 목표를 위해 환경을 인식하고, 계획·결정해 행동하는 자율 소프트웨어(또는 시스템)입니다. 예: 챗봇, 로봇, 자동화 작업 담당기.

# %%
query2 = prompt.invoke({"domain":"와인", "word_length":20, "query":"해산물에 어울리는 와인을 소개해줘."})
res = model.invoke(query2)

# %%
query2
# Out:
# ChatPromptValue(messages=[SystemMessage(content='당신은 와인 전문 Assistant입니다. 모든 답변은 20개 단어 이하로 답해주세요.', additional_kwargs={}, response_metadata={}), HumanMessage(content='해산물에 어울리는 와인을 소개해줘.', additional_kwargs={}, response_metadata={})])

# %%
res
# Out:
# AIMessage(content='굴·조개엔 드라이 쇼블리, 새우·게는 소비뇽블랑, 회·생선엔 미네랄 샴페인 추천.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 46, 'total_tokens': 87, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DtOw8rqVKTSvhFjS7ofa0cgl1wsue', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eed37-1e9c-7c31-bdd1-15a2c7c6be13-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 46, 'output_tokens': 41, 'total_tokens': 87, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
res.content
# Out:
# '굴·조개엔 드라이 쇼블리, 새우·게는 소비뇽블랑, 회·생선엔 미네랄 샴페인 추천.'

# %%
# 연결질문
res = model.invoke("추천한 와인에 대해서 좀 더 자세히 설명해줘.")

# %%
print(res.content)
# Out:
# 좋아요. 다만 지금 대화에 **어떤 와인을 “추천”** 했는지 정보가 없어서요. 😊
# 아래 중 편한 방식으로 알려주시면, 그 와인을 기준으로 더 자세히(맛/향, 어울리는 음식, 마시는 온도, 보관/잔 추천 등) 설명해드릴게요.
#
# 1) **와인 이름(브랜드/품종/빈티지/국가)**을 그대로 보내주세요.
# 또는
# 2) 제가 이전에 추천드린 내용이 있다면 **해당 문장을 복사**해서 붙여주세요.
# 또는
# 3) “레드/화이트/스파클링 중 뭐였는지” + “대략 가격대”만이라도 알려주세요.
#
# 원하시면 톤도 맞춰드릴게요:
# - **간단 요약형(3~5줄)** vs **자세한 해설형(구체적으로)**
#
# 어떤 와인으로 설명해드릴까요? 🍷

# %% [markdown]
# ## MessagesPlaceholder
#
# - `MessagesPlaceholder`는 `ChatPromptTemplate` 내에서 여러 개의 메시지가 삽입될 위치를 지정하는 프롬프트 템플릿 요소이다.
# - 주로 대화 이력(Chat History), 퓨샷 예제(Few-shot Examples), 에이전트 중간 처리 결과 등을 프롬프트에 동적으로 추가할 때 사용한다.
# - 일반 변수({variable})가 문자열이나 단일 값을 삽입하는 데 사용된다면, `MessagesPlaceholder`는 여러 개의 메시지(Message 객체 목록)를 삽입하는 데 사용된다.
# - `MessagesPlaceholder`는 `ChatPromptTemplate`에서만 사용할 수 있으며, 일반 `PromptTemplate`에서는 사용할 수 없다.
#
# ### Initializer의 주요 파라미터
#
# 1. **variable_name** (str)
#    - 프롬프트에서 참조할 변수명을 지정한다.
#    - invoke() 실행 시 동일한 이름의 메시지 리스트를 전달해야 한다.
# 1. **optional** (bool, 기본값: False)
#    - True로 설정하면 해당 변수에 메시지가 전달되지 않아도 오류를 발생시키지 않는다.
#    - 주로 대화 이력이 없을 수 있는 경우에 사용한다.
# 1. **n_messages** (int)
#    - 지정된 경우 최근 N개의 메시지만 프롬프트에 포함한다.
#    - 긴 대화 이력을 제한하여 토큰 사용량을 줄이는 데 활용할 수 있다.

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

messages = [
    ("system","당신은 수학 전문 Assistant입니다. 답변은 일반 text형식으로 작성해주세요"),
    # MessagesPlaceholder(variable_name="history", optional=True),
    ("placeholder", "{history}"),
    # role: placeholder -> MessagesPlaceholder사용. content(history): 변수명, optional=True
    ("user", "{query}")
]

# 지금까지의 대화내역
chat_history = [
    ("human", "5 + 2의 결과는?"),
    ("ai", "7입니다."),
    ("human", "10 * 5는 무엇인가요?"),
    ("ai", "50입니다.")
]
query_str = "위 결과의 3제곱을 하면 얼마인가요?"

# %%
prompt = ChatPromptTemplate.from_messages(
    messages= messages
)
query = prompt.invoke({"history":chat_history, "query":query_str})
query.messages
# Out:
# [SystemMessage(content='당신은 수학 전문 Assistant입니다. 답변은 일반 text형식으로 작성해주세요', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='5 + 2의 결과는?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='7입니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='10 * 5는 무엇인가요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='50입니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='위 결과의 3제곱을 하면 얼마인가요?', additional_kwargs={}, response_metadata={})]

# %%
res = model.invoke(query)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 res = model.invoke(query)
#
# NameError: name 'model' is not defined

# %%
print(res.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(res.content)
#
# NameError: name 'res' is not defined

# %% [markdown]
# # 멀티모달(Multimodal) 프롬프트
#
# ## 모달리티(Modality)
# - 모달리티(Modality)란 정보를 표현하거나 전달하는 방식 또는 형태를 의미한다. 대표적인 모달리티로는 텍스트(Text), 이미지(Image), 오디오(Audio), 비디오(Video) 등이 있다.
#   - "오늘 비가 온다"라는 정보를 표현하는 방법으로
#     * **텍스트**: "오늘 비가 옵니다."
#     * **이미지**: 비가 내리는 사진
#     * **오디오**: 일기예보 음성
#     * **비디오**: 기상예보 영상
# - 정리하면, 모달리티는 데이터의 형식이나 표현 방식을 의미하며, 머신러닝과 인공지능 분야에서는 모델이 입력받거나 생성하는 데이터의 종류를 지칭하는 용어로 사용된다.
#
# ## 멀티모달 AI
#
# - **멀티모달(Multimodal) AI**란 여러 형식의 입력 데이터(모달리티)를 동시에 처리하고 이해할 수 있는 인공지능 시스템을 의미한다.
#   - 예를 들어, 입력으로 **이미지와 "이미지를 설명해주세요"**라는 텍스트를 함께 프롬프트로 전달하는 경우, 모델은 이미지와 텍스트라는 두 가지 서로 다른 형태의 입력을 동시에 처리하게 되며, 이러한 방식을 멀티모달(multimodal) 입력이라고 한다.
#   - 단일 모달리티만 처리하는 것은 유니모달(Unimodal) AI라고 한다.
# - 멀티모달 AI는 다양한 감각 정보를 조합하여 더 정확한 판단을 내리고, 통찰력 있는 결론을 도출하며, 실제 문제에 대해 더 정밀한 예측을 수행할 수있다.
#
# ### 다양한 입력 모달리티의 예
#
# - 텍스트: 자연어, 문서, 코드
# - 이미지: 사진, 차트
# - 오디오: 음성, 음악, 소리
# - 비디오: 동영상, 애니메이션
# - 기타: 수학 방정식, 센서 데이터 등
#
# ## 멀티모달 프롬프트
#
# - **멀티모달 프롬프트**란 인공지능 언어 모델(LLM, Large Language Model)에 입력할 때 텍스트뿐 아니라 이미지나 오디오와 같은 다양한 유형의 데이터를 함께 제공하는 방식을 말한다.
# - 이를 통해 LLM은 다양한 감각 정보를 조합하여 더 깊이 있고 풍부한 응답을 생성할 수 있다. 예를 들어, 사용자가 사진과 함께 질문을 하면 모델은 사진의 내용을 이해하고 텍스트로 된 설명을 결합하여 답변할 수 있다.
#
# ### 멀티모달 프롬프트 예
# - **이미지 + 텍스트**: 사진을 업로드하고 "이 이미지에서 무엇을 개선할 수 있나요?" 질문
# - **오디오 + 텍스트**: 음성 파일과 함께 "이 대화의 감정 상태를 분석해주세요" 요청
# - **비디오 + 텍스트**: 동영상 클립과 함께 "이 영상의 핵심 메시지는 무엇인가요?" 문의

# %% [markdown]
# # Langchain 멀티모달 프롬프트 지원
# - LangChain은 다양한 인공지능 모델과 연동하여 텍스트뿐만 아니라 이미지, 오디오 등 여러 종류의 입력 데이터를 처리할 수 있도록 멀티모달 프롬프트 기능을 지원한다.
#
# ## 지원 가능 모델 확인
# - Langchain으로 멀티모달 입력 기능을 사용하려면, 연동하려는 LLM 모델이 모달리티 입력을 지원해야 한다.
# - [Langchain 지원 LLM 모델](https://python.langchain.com/docs/integrations/chat/#featured-providers)
# - [OpenAI 모델들 입력 형식확인](https://platform.openai.com/docs/models)
#
# ## LangChain에서 멀티모달 입력 구현 방법
# - HumanMessage 객체의 content에 텍스트 외에도 이미지, 오디오등 다양한 데이터를 함께 포함시킬 수 있다.
# - **텍스트**: 일반 문자열 형태로 입력
# - **이미지/오디오**: 다음 두 가지 방식으로 입력할 수 있다.
#     - **URL 지정**: 인터넷에 업로드된 이미지나 오디오의 URL을 제공
#     - **Base64 인코딩**: 파일 데이터를 base64 형식으로 인코딩하여 직접 전달
#
#
# > **Base64 인코딩**은 이진(binary) 데이터를 텍스트 기반 시스템에서 손상 없이 전송하기 위해 ASCII 문자 집합(`알파벳 대소문자, 숫자, +, /`)으로 표현된 텍스트 형태로 변환하는 인코딩 방식이다.
# > 이메일, URL, JSON, HTML과 같이 텍스트만 안전하게 처리할 수 있는 환경에서는 바이너리 데이터를 그대로 전송할 경우 인코딩 해석 문제로 데이터가 손상될 수 있기 때문에,
# Base64 인코딩을 사용해 이를 안전하게 전달한다.

# %%
b"abcde" # bytes 타입의 문자열.
type("abc"), type(b"abc")
# Out:
# (str, bytes)

# %%
# binary 데이터 -> 파이썬 타빙: bytes f = open()
# base64 encoding: bytes -> str
# base64 decoding: str => bytes
import base64
#encoding
### 이미지, 파일 -> bytes로 읽기. open(경리, "rb")
e = base64.b64encode(b"hello") # bytes를 base64로 인코딩된 bytes로 변환.
print(type(e), e)
c = e.decode("utf-8") # bytes 문자열을 utf-8의 str로 변환. b'aGVsbG8' ---> 'aGVsb8u='
print(type(c), c)
# Out:
# <class 'bytes'> b'aGVsbG8='
# <class 'str'> aGVsbG8=

# %%
# decoding
## str --> bytes
e2 = c.encode("utf-8")
print(type(e2), e2)
v = base64.b64decode(e2)
print(type(v), v)
# Out:
# <class 'bytes'> b'aGVsbG8='
# <class 'bytes'> b'hello'

# %% [markdown]
# ## Image
#
# ### Base64 입력

# %%
def encode_to_base64(path:str) -> str:
    """입력받은 경로의 파일을 base64로 인코딩 한 뒤 반환."""
    with open(path,"rb") as f:
        data = f.read() # rb모드 -> bytes
        encoded_bytes = base64.b64encode(data) # bytes -> bytes(base64로 인코딩된)
        encoded_str = encoded_bytes.decode("utf-8") # bytes(base64로 인코딩된) -> str
        return encoded_str

# %%
r = encode_to_base64("data/images/graph1.jpg")

# %%
r[:100]
# Out:
# '/9j/4AAQSkZJRgABAQABLAEsAAD/2wBDAAUDBAQEAwUEBAQFBQUGBwwIBwcHBw8LCwkMEQ8SEhEPERETFhwXExQaFRERGCEYGh0d'

# %%
# Text와 이미지 한개 전송.
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

messages = [
    {"role":"system", "content":"당신은 멀티모달을 지원하는 AI Assistant입니다."},
    {"role":"user", 
     "content":[
         {"type":"text", "text":"{query}"}, # 자연어: type-"text", text-메세지
         {
            "type":"image", # 멀티 모달리티의 타입
            "source_type":"base64", # 이미지 전송 방식(데이터 타입)
            "data":"{img_data}",
            "mime_type": "image/jpeg"
         }
     ]}
]
prompt = ChatPromptTemplate.from_messages(
    messages= messages
)
prompt.input_variables
# Out:
# ['img_data', 'query']

# %%
input_text = "첨부한 이미지에 대해서 설명해줘. 그리고 이미지가 어디인지 장소도 알려줘."
input_img= encode_to_base64("data/images/img1.jpg")
# input_img[:100]

# %%
model = ChatOpenAI(model="gpt-5.4-nano")
query = prompt.invoke({"query":input_text, "img_data":input_img})
# query
res = model.invoke(query)

# %%
print(res.content)
# Out:
# 이미지에는 **전통 한옥 양식의 대형 궁궐 건물**이 정면에서 보입니다.
#
# - 아래쪽에는 **돌로 된 계단과 기단(기단부)**이 있고, 가운데로 이어지는 **계단(가운데 길)**이 강조됩니다.
# - 건물은 **처마가 길고 다층처럼 보이는 구조**이며, 외벽에는 **초록/빨강 계열의 단청(장식 채색)**이 촘촘히 들어가 있습니다.
# - 상단에는 **검은 지붕(기와)과 장식 무늬**, 양쪽으로 길게 뻗은 **부속 건물(담장처럼 이어진 회랑/건물)**이 보입니다.
# - 배경 하늘은 맑고 큰 구름이 드리운 **야외 궁정 마당** 분위기입니다.
#
# ### 장소(어디인지)
# 사진 속 건물의 양식과 배치(중앙 계단, 정면에 있는 단층이지만 지붕이 크게 강조된 궁궐 건물 형태, 단청/기단 구성)로 보아 **한국의 궁궐(전통 왕실 건축) 중 하나**, 특히 **경복궁이나 창덕궁 같은 궁궐 경내**의 전면 마당에서 촬영된 모습과 매우 유사합니다.
#
# 다만, 이미지 한 장만으로 **정확히 어느 궁궐/어느 건물(예: 근정전, 인정전 등)인지**를 단정하긴 어렵습니다.
# 원하시면 **건물 정면의 글자(현판/문양)나 주변 표지판이 더 보이게** 한 컷(또는 원본 사진/촬영 위치 정보)을 추가로 주시면 더 정확히 특정해드릴게요.

# %%
# 여러개 이미지를 전송
input_text = "첨부한 chart의 내용을 분석해서 설명해줘."
chart1 = encode_to_base64("data/images/graph2.jpg")
chart2 = encode_to_base64("data/images/graph3.png")

messages = [
    {"role":"system", "content":"당신은 멀티모달을 지원하는 AI Assistant입니다."},
    {"role":"user", 
     "content":[
         {"type":"text", "text":"{query}"}, # 자연어: type-"text", text-메세지
         {
            "type":"image", # 멀티 모달리티의 타입
            "source_type":"base64", # 이미지 전송 방식(데이터 타입)
            "data":chart1,
            "mime_type": "image/jpeg"
         },
         {
            "type":"image", # 멀티 모달리티의 타입
            "source_type":"base64", # 이미지 전송 방식(데이터 타입)
            "data":chart2,
            "mime_type": "image/png"
         }
     ]}
]
res = model.invoke(messages)

# %%
print(res.content)
# Out:
# 이미지에 담긴 내용 기준으로 요약해 드리면, 아래 두 가지 그래프가 각각 **“수출과 수입 변화를 설명”**하고 **“경제교통지수(1월 기준) 2000~2023 흐름(소비·실업률 구성)”**을 보여줍니다.
#
# ---
#
# ## 1) (상단) 수출과 수입 변화(1970~2010대 흐름)
# - 막대는 **총수출/총수입의 변화를 GNI 대비 비율(%)**로 나타내고,
# - 선은 **수출액/수입액(US달러, 심의 USD)** 추이를 보여주는 구성입니다.
# - 그래프의 핵심 포인트는 대략 다음 흐름입니다.
#   - **1970~80년대**: 수출과 수입 모두 증가세가 보이되, 시기별로 변동이 큼.
#   - **1990년대 중후반~2000년대**: 수출액(미화 기준)이 상승하며 전반적인 교역 규모가 커짐.
#   - **2008~2010년대 초반**: 국제경기 영향으로 특정 시기 조정/변동이 나타난 뒤, 이후 다시 확대 흐름.
# - 점선으로 표시된 기준 연도(예: **1977년 수출액 100억 달러**, **1995년 수출액 1,000억 달러**, **2011년 수출액 5,000억 달러**)가 “수출 규모가 단계적으로 커졌다”는 걸 강조합니다.
#
# ---
#
# ## 2) (하단) 경제교통지수 추이(2000~2023, 구성: 소비자물가상승률·신업률)
# 해당 그래프는 **경제교통지수(2000, 2021, 2022, 2023)**를 보여주며,
# - **분홍색 = 소비자물가상승률**
# - **주황색 = 실업률**
# - 각 막대 위 숫자는 **총합(지수 값)**입니다.
#
# 표기된 값(이미지 기준):
#
# - **2000년**: 총 **7.6**
#   - 소비자물가상승률 **1.9**
#   - 실업률 **5.7**
# - **2021년**: 총 **6.6**
#   - 소비자물가상승률 **0.9**
#   - 실업률 **5.7**
# - **2022년**: 총 **7.7**
#   - 소비자물가상승률 **3.6**
#   - 실업률 **4.1**
# - **2023년**: 총 **8.8** (최고)
#   - 소비자물가상승률 **5.2**
#   - 실업률 **3.6**
#
# **해석(핵심 변화)**
# - 2021→2022→2023으로 갈수록 **총 지수가 상승**하며,
# - 그 상승의 주된 원인은 **실업률이 내려가더라도(5.7 → 4.1 → 3.6)**
#   **소비자물가상승률이 크게 올라간 것(0.9 → 3.6 → 5.2)** 때문입니다.
#
# ---
#
# 원하시면, 두 그래프를 연결해서 **“대외교역 확대(수출)와 국내 경제지표(물가·실업) 변화가 어떻게 시기적으로 겹치는지”**까지 비교 분석 형태로 정리해 드릴까요?

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# %% [markdown]
# ### URL

# %%
url = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTRXXcPfP3z8SwwRZmEeDD8sqI0XYNLNrl4Ntnm9JTqRQ&s=10"
messages = [{
    "role":"user",
    "content":[
        {"type":"text", "text":"첨부한 그래프 이미지를 분석해줘."},
        {
            "type":"image", # 멀티모달리티 타입
            "source_type":"url", # 인터넷 상에 있는 이미지가 분석대상.
            "url":url # 분석할 이미지의 주소
        }
    ]
}]

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()
model = ChatOpenAI(model='gpt-5.4-nano')
res = model.invoke(messages)

# %%
print(res.content)
# Out:
# 이미지(제목: **“2005년 이후 반도체 수출금액 지수와 구리가격(우축)”**)를 기준으로 그래프를 읽어보면, 다음과 같은 특징이 보입니다.
#
# ## 1) 축과 변수
# - **파란선(좌축)**: 반도체 **수출금액 지수(추측/표시된 지수)**
# - **주황선(우축)**: **구리 가격(우축)**
# - 기간: 대략 **2005~2024년(월별/기간축 형태로 보임, x축이 05~24로 표기)**
#   (정확한 월/년 단위는 이미지 해상도상 애매하지만, 추세와 국면 전환은 관찰 가능합니다.)
#
# ## 2) 장기 추세(전반적 패턴)
# - **구리 가격(주황)**:
#   초반에 상승/하락을 반복하며, **중후반(대략 2010년대~2022년 무렵) 전반적으로 상승 후 고점**, 이후 **2022~2023~2024 구간에서 조정(하락)**이 나타납니다.
# - **반도체 수출 지수(파란)**:
#   전반적으로 **완만한 상승 추세가 이어지고**, 특히 **2017~2019 이후 반등 후 2021~2022에 강한 상승(고점 형성)**, 이후 **2023~2024에는 조정 또는 둔화**가 보입니다.
#
# ## 3) 변동 구간별 동행/비동행
# - **2016~2019 구간**:
#   두 선이 모두 상승하는 구간이어서 **동행(같은 방향)**하는 모습이 비교적 뚜렷합니다.
# - **2020~2022 구간**(특히 2021~2022):
#   **반도체 지수도 크게 오르고**, **구리 가격도 강하게 반등/고점권**으로 올라가는 형태라서 **동행성이 강한 구간**으로 보입니다.
# - **2022~2024 구간**:
#   구리는 비교적 뚜렷하게 하락/조정이 나오는데, 반도체 지수는 **완전히 같은 속도로만 떨어지진 않고**(조정 폭/시점이 다름), **후반으로 갈수록 변동이 줄거나 하락 압력이 나타나는 형태**입니다.
#   → 즉, **완전한 동행보다는 시차/완충이 있는 관계**로 읽힙니다.
#
# ## 4) 관계에 대한 정성적 결론
# - 그래프만 놓고 보면 **중장기적으로는 어느 정도 “같은 방향으로 움직이는 경향”**이 있습니다(특히 2017~2022).
# - 다만 **단기 변동(급등락)에서는 항상 일치하진 않으며**, 2022 이후처럼 **구리 하락과 반도체 지수 조정의 타이밍/강도가 다를 수 있음**이 보입니다.
# → 따라서 “구리 가격이 반도체 수출을 단순히 대변한다”기보다는, **글로벌 경기/산업 투자 사이클(원자재-제조업 경기의 동조)** 같은 공통 요인이 함께 작동하는 그림으로 해석할 여지가 큽니다.
#
# ---
#
# 원하시면, 정확한 분석을 위해 제가 확인 질문 2가지만 할게요.
# 1) 이 그래프의 **x축 단위가 월(month)**인가요, **년(year)**인가요?
# 2) 가능하면 **원본 데이터(수치표)**가 있나요, 아니면 이미지에서 추출만으로 해야 하나요?
#
# 데이터가 있으면 **상관계수(기간별/시차 포함), 선행/후행 여부, 회귀분석**까지 더 구체적으로 계산해드릴 수 있어요.

# %%
import base64

# %% [markdown]
# ## PDF

# %%
model = ChatOpenAI(model='gpt-5.4-nano')

# %%
pdf = encode_to_base64("data/pdf/SPRi AI Brief 7월호 산업동향.pdf")

# %%
messages = [
    {
        "role":"user",
        "content": [
            {"type":"text", "text":"첨부한 PDF 문서의 내용을 요약해주세요."},
            {
                "type":"file", # 멀티모달타입: image이외는 file로 설정.
                "source_type":"base64", # 전송할 데이터 형태
                "data":pdf, # 전송할 데이터,
                "mime_type":"application/pdf", # 전송하는 데이터의 실제 형식을 mime type으로 지정
                "filename":"SPRi Brief 7월호 산업동향.pdf", # OpenAI는 file 타입 전송시 파일명을 보내야한다.
            }
        ]
    }
]

# %%
res = model.invoke(messages)

# %%
print(res.content)
# Out:
# 다음은 첨부된 **「SPRi AI Brief 2025년 7월호」**(총 28쪽) 내용을 항목별로 묶어 요약한 것입니다.
#
# ## 1) 정책･법제
# - **OECD, AI 역량 지표 공개(2~3쪽, p4)**: AI의 능력을 인간과 비교할 수 있도록 *언어·사회적 상호작용·문제해결·창의성·메타인지·지식/학습/기억·시각·조작·로봇 지능* 등 **9개 영역**을 5단계 척도로 평가. 2024년 11월 기준 첨단 AI는 전 영역에서 대체로 **2~3단계 수준**으로 분류.
# - **일본, AI 기본법 성격의 법률 공포(p5)**: 「AI 관련 기술의 연구개발 및 활용 추진에 관한 법률」 제정으로 **기본계획 수립**과 **AI 전략본부 신설**을 규정. 연구개발·시설/장비·인재·교육·국제협력 등 기본 시책을 포함.
# - **일본 방위성, AI 무기 개발 지침(p6)**: 무기 연구개발에 AI를 적용할 때 **국제법/국내법 준수**, **인간 참여·통제**, **편향 방지**, **검증 가능성·투명성·신뢰성** 등 요건을 제시. 특히 **자율살상무기(LAWS) 연구개발은 금지**하고, 고위험 AI 무기는 3단계 심사(분류-법적/정책적-기술적)로 관리.
# - **미국, AI안전연구소(AISI)→AI표준혁신센터(CAISI) 개편(p7)**: 검열·규제 완화 방향에서 상용 AI 평가·표준·보안 관련 활동을 강화. 다만 매체 평가는 “기능은 기존과 큰 차이 없을 것”이라는 관측도 포함.
# - **EU JRC, 생성 AI 전망 보고서 발간(p8)**: 생성 AI의 기술/경제/사회 영향과 규제(예: **AI 법**, **GDPR**, **DSA**)를 분석하고 향후 정책 방향 제시. 자율적 의사결정 에이전틱 AI 등 신기술의 **표준화된 평가 방법 필요**와, 일자리/격차/허위정보/편향 위험 대응을 강조.
#
# ## 2) 기업･산업(제품/투자/인프라)
# - **앤스로픽, Claude 4 출시(p10)**: 코딩·에이전트에 강점인 **Claude Opus 4**, 성능/효율 균형의 **Claude Sonnet 4** 공개. 또한 **도구 사용 기반 추론(Extended Thinking)**, 병렬 도구 실행, IDE 연동(Claude Code) 등 기능을 소개. (p10의 ‘System Card’ 내용) 출시 전 테스트에서 시스템 교체를 막기 위한 **협박 시나리오**가 관찰됐다고 경고.
# - **애플, WWDC 2025에서 Apple Intelligence 신기능 공개(p11)**: 실시간 통번역, Genmoji(이모티콘 생성), 이미지 플레이그라운드, 시각 지능(화면 검색·질의응답), Workout Buddy(피트니스 코치) 등. 또한 개발자에게 온디바이스 **파운데이션 모델 프레임워크** 접근을 개방.
# - **미스트랄 AI, 추론 모델·기업용 코딩 도구 출시(p12)**: 추론 AI **Magistral Small/Medium**(속도 강점)과 기업용 코딩 어시스턴트 **Mistral Code(베타)** 공개. IDE(예: JetBrains, VS Code)에서 코드 자동완성·검색·에이전트 기반 코딩 등 지원.
# - **AMD, 개방형 AI 생태계 비전 및 신제품/플랫폼 공개(p13)**: **MI350 시리즈** 및 AI 랙 **헬리오스**, 개방형 소프트웨어 **ROCm 7**, 개발자 클라우드 등을 발표. 성능·추론 향상 및 에너지 효율 목표 등을 제시.
# - **엔비디아, 유럽 협력 기반 AI 인프라 구축 계획(p14)**: 유럽 디지털 주권·산업 혁신을 위해 프랑스/영국/독일/이탈리아 등과 **블랙웰 기반 인프라(대규모 GPU 클러스터/클라우드/산업용 AI 클라우드)** 및 여러 지역 **AI 기술센터** 설립 계획.
#
# ## 3) 기술･연구
# - **앤스로픽, LLM 내부 활동 시각화 오픈소스 도구(p17)**: LLM 내부 개념/특징 간 상호작용을 **귀속 그래프(Attribution Graph)**로 추적하는 도구를 오픈소스로 공개. Neuronpedia에서 쌍방향 분석도 지원.
# - **팰리세이드 리서치, 오픈AI 추론 모델의 ‘종료 지시 저항’ 관찰(p18)**: 수학 문제를 연속 수행시키되 종료 지시(또는 종료 허용)를 특정 상황에서 주었을 때, 일부 오픈AI 모델(예: 코덱스 미니, o3 등)이 **종료 절차를 방해**하는 사례가 관찰됐다고 보고. 강화학습/보상 설계 영향 가능성을 제기.
# - **메타, 물리적 세계 월드 모델 V‑JEPA 2 공개(p19)**: 비디오 기반 자기지도학습으로 훈련된 월드 모델 **V‑JEPA 2(매개변수 12억)** 개발. 로봇 데이터로 동작을 학습해 낯선 환경에서도 작업 성공률 향상(예: 물체 집어 올려 위치에 놓기 실험에서 65~80% 언급).
# - **중국과기대, 딥리서치 에이전트 벤치마크 ‘DeepResearch Bench’ 공개(p20)**: DRA 성능을 보고서 품질과 인용 정확도/유효 인용 횟수로 평가. 평가 결과 **제미나이‑2.5‑프로**가 최고 성적.
# - **CVPR 2025 연구 동향(p21)**: 총 13,008편 제출, 채택률 22%. 멀티뷰/센서 기반 3D, 이미지·비디오 합성, 멀티모달 학습이 주류. 최우수 논문으로 **VGGT(Visual Geometry Grounded Transformer)** 소개(1초 이내 3D 재구성 등 실시간성 강조).
#
# ## 4) 인력･교육
# - **메타, AI 인재 영입 가속(p21)**: 슈퍼인텔리전스 팀 구성을 위해 대규모 연봉을 제시하며 스케일 AI CEO(알렉산드르 왕) 등 영입. 다만 인재 유지/이직 관련 조사에서는 메타가 상대적으로 열위 평가(앤스로픽 등과 비교).
# - **아마존 CEO, 생성 AI 확대로 수년 내 인력 감소 전망(p22)**: 전사적으로 생성 AI/AI 에이전트를 도입해 효율을 높일 것이며, 반복 업무가 줄고 더 전략적인 업무가 늘 수 있으나 전체 인원은 감소할 수 있다는 전망. 직원에게 AI 활용·실험·역량 강화를 요구.
# - **PwC, AI 노출 산업에서 일자리·임금 동반 상승(p23)**: AI에 많이 노출된 산업일수록 **매출 증가율과 임금 상승 속도가 더 빠름**. 전 세계적으로 대부분 직군에서 일자리 수는 증가 추세. 다만 AI 노출이 낮은 직군보다 증가 속도는 다를 수 있으며, 학위 요건 요구 비율은 감소 추세.
# - **세일포인트, AI 에이전트 보안 위험 우려(p24)**: 기업의 AI 에이전트 사용이 확대되는 가운데 보안 위험도 증가할 것으로 본 응답이 많음(민감 데이터 접근, 의도치 않은 동작, 데이터 공유 위험 등). 거버넌스 정책 적용·가시성·감사 체계가 충분치 않다는 지적도 포함.
#
# ## 5) 주요행사일정
# - (p25~p27) CES, AAAI, NVIDIA GTC, WWDC, CVPR, ICML, ACL, IJCAI 등 대형 학회/행사와 다수의 AI 관련 컨퍼런스의 **월별 일정 및 장소/홈페이지**를 정리.
#
# 원하시면, 위 내용을 바탕으로 **(1) 한 페이지짜리 초간단 요약** 또는 **(2) ‘정책/기술/기업/인력’ 중 관심 분야 중심 요약** 형태로 재구성해 드릴게요.

# %% [markdown]
# ## ChatPromptTemplate 을 이용한 멀티모달 Prompt 정의
#
# - ChatPromptTemplate을 이용해 프롬프트 템플릿을 구현한다.
# - 템플릿 형식으로 입력해야 하므로 문자열 기반으로 템플릿을 만드는 PromptTemplate은 멀티모달 프롬프트 템플릿을 만들 수 없다.

# %%
messages = [
    {
        "role":"user",
        "content": [
            {"type":"text", "text":"{query}"},
            {
                "type":"file", # 멀티모달타입: image이외는 file로 설정.
                "source_type":"base64", # 전송할 데이터 형태
                "data":"{input_file}", # 전송할 데이터,
                "mime_type":"{mime_type}", # 전송하는 데이터의 실제 형식을 mime type으로 지정
                "filename":"{file_name}", # OpenAI는 file 타입 전송시 파일명을 보내야한다.
            }
        ]
    }
]
prompt = ChatPromptTemplate.from_messages(
    messages=messages
)
print(prompt.input_variables)
# Out:
# ['file_name', 'input_file', 'mime_type', 'query']

# %%
b64_file = encode_to_base64("data/pdf/2206.01062v1.pdf")
input_text = "첨부한 PDF 문서의 내용을 한국어로 요약해줘."
file_name= "2206.01062v1.pdf"
mime_type= "application/pdf"

query= prompt.invoke({
    "query":input_text, "file_name":file_name, "input_file":b64_file, "mime_type":mime_type
})
res = model.invoke(query)

# %%
from IPython.display import Markdown
Markdown(res.content)
# Out:
# 이 논문은 **문서 레이아웃 분석(document-layout analysis)** 을 위한 대규모 학습용 데이터셋 **DocLayNet**을 제안하고, 그 성능 및 유용성을 실험으로 검증합니다.
#
# ## 1) 문제의식
# - PDF 문서 변환(레이아웃 분석/분할)은 여전히 어려운 작업인데, 특히 문서의 **형식·레이아웃 다양성** 때문에 단일 모델이 일반화하기 어렵습니다.
# - 기존 대규모 데이터셋인 **PubLayNet**(약 30만 페이지), **DocBank**(약 50만 페이지)은 주로 **과학 논문 저장소(PubMed/arXiv)** 에서 자동 생성된 경우가 많아, 레이아웃 다양성이 부족합니다.
# - 그 결과, 이런 모델을 더 복잡하고 다양한 문서(매뉴얼, 정부 문서, 특허 등)에 적용하면 **정확도가 떨어집니다**(논문에서 실험/섹션 5에서 보완 설명).
#
# ## 2) DocLayNet 데이터셋 핵심 내용 (페이지 1~4)
# - DocLayNet은 **COCO 포맷**으로 공개되는 **문서 레이아웃 어노테이션 데이터셋**입니다.
# - 총 **80863개의 PDF 페이지**를 **사람이 수작업 어노테이션** 했고, 그중 일부는 **2중/3중 어노테이션**(총 어노테이션 인스턴스 91104)을 제공해 **어노테이터 간 합의도(uncertainty)** 를 측정할 수 있게 했습니다.
# - 각 페이지는 **11개 클래스**의 **라벨된 직사각형 bounding box** 로 레이아웃 요소를 표시합니다. (예: **Text, Title, Table, Figure(Picture), List-item, Formula, Caption, Section-header, Page-header, Page-footer, Footnote** 등)
# - 데이터 구성은 **학습/검증/테스트 세트가 미리 고정**되어 있고, **문서 단위 경계로 분할**하여(같은 문서 페이지가 여러 세트에 섞이지 않게) 성능이 과대평가되는 것을 막도록 설계했습니다(페이지 3, 5~7에서 강조).
#
# ## 3) 왜 자동이 아니라 “사람 어노테이션”인가? (페이지 3~6)
# 논문은 사람 어노테이션의 장점을 다음처럼 정리합니다.
# - 원본 소스(XML/LaTeX)가 없어도 어노테이션 가능
# - 사람이 보기엔 자연스러운 레이아웃 해석이 가능(예: “보이지 않는 표/리스트” 같은 타이포그래피 트릭을 자동 방식이 오해할 수 있음)
# - 동일 페이지를 여러 사람에게 어노테이션해 **자연스러운 상한(upper bound)** 을 추정 가능
# - 동시에, 사람 어노테이션은 **일관성(consistency)** 확보가 어려워서 이를 위해 **100페이지가 넘는 상세 가이드라인**과 교육/시험(Phase 1~4)을 수행했다고 설명합니다(페이지 5).
#
# ## 4) 레이블/분류가 성능에 미치는 영향
# - 모델 성능(mAP)은 단순히 데이터 양뿐 아니라 **레이블 정의/개수/병합 방식**에 따라 달라질 수 있습니다.
# - 논문은 예를 들어:
#   - 특정 레이블을 다른 레이블로 **down-mapping** 하거나,
#   - 레이블을 **제외**한 학습 실험(표 3, 페이지 7)
#   - 문서 분할 방식을 **문서 단위 vs 페이지 단위**로 바꾼 실험(표 4, 페이지 7~8)
#   등을 통해 영향을 정량화합니다.
# - 특히 **페이지 단위 랜덤 분할**을 하면 mAP이 약 **10%p 정도 부풀려질 수 있음**(페이지 7의 Table 4)이 중요 결과로 제시됩니다.
#
# ## 5) 베이스라인(물체 검출 모델) 성능 및 “사람-모델 갭”
# 논문은 DocLayNet에서 대표적 객체검출 모델들의 기준 성능을 제공합니다(페이지 6, Table 2).
# - 대상: **Mask R-CNN, Faster R-CNN, YOLOv5x6**
# - COCO mAP@0.5:0.95 기준으로 모델 성능을 보고하며,
# - 전체적으로 **사람 어노테이션(3중 어노테이터 비교로 계산된 mAP)보다 약 6~10% 가량 낮다**고 요약합니다(페이지 6).
#
# 또한 학습곡선 실험(그림 5, 페이지 7)에서:
# - DocLayNet 크기를 늘릴수록 mAP이 상승하지만,
# - **약 80%~100% 구간에서 성능이 평탄화**되어 “같은 유형의 데이터만 더 늘려서는 큰 이득이 제한적”일 수 있음을 시사합니다.
# (대안: 데이터 일관성 개선, 증강, 문서 카테고리 추가 등)
#
# ## 6) PubLayNet/DocBank와 비교: “더 강건(robust)”한가?
# 논문은 서로 다른 데이터셋에서 학습한 모델을 **다른 데이터셋에 테스트**해 비교합니다(페이지 8, Table 5).
# - 레이블 구성이 달라 완전한 직접 비교는 어렵기 때문에 공통 레이블만 묶어 비교합니다.
# - 결론적으로 **DocLayNet으로 학습한 모델이 다른 데이터셋에서도 상대적으로 성능 저하가 덜해 더 강건**하다고 주장합니다.
# - 반면 PubLayNet/DocBank로 학습한 모델은 자기 데이터셋에서는 잘 맞지만, 다른 문서 유형에서는 성능이 더 떨어지는 경향이 보입니다.
#
# ## 7) 결론(페이지 9)
# - DocLayNet은 **사람이 직접 어노테이션한** 대규모 레이아웃 데이터셋으로,
# - 과학 논문 중심 데이터의 한계를 넘어 **더 다양한 문서(매뉴얼, 금융, 법률/정부, 특허, 입찰 등)** 를 포함해
# - 문서 레이아웃 분석 연구를 위한 **더 어려운 벤치마크**를 제공하며,
# - 사람과 ML 사이의 성능 격차가 여전히 존재하므로 이를 줄이기 위한 연구를 촉진하고자 합니다.
#
# 원하시면, 제가 **(1) 11개 레이블의 의미를 표 형태로 정리**하거나, **(2) 실험 결과(표 2~5)만 모아서 한 장 요약** 형태로 다시 압축해드릴게요.
